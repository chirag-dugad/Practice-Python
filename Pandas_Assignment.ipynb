# %%
print("Hii, Chirag")
# Out:
# Hii, Chirag

# %%
import pandas as pd
import numpy as np

# %%
a = pd.DataFrame([1,2,3])
a
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
a = pd.Series([1,2,3,4] , index=["a" , "b" , "c" , "d"])
a
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
a = pd.DataFrame(np.arange(10,21))
a
# Out:
#      0
# 0   10
# 1   11
# 2   12
# 3   13
# 4   14
# 5   15
# 6   16
# 7   17
# 8   18
# 9   19
# 10  20

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst = ['a', 'b', 'c']
df = pd.DataFrame(lst)
df
# Out:
#    0
# 0  a
# 1  b
# 2  c

# %%
data = {'Name': ['John', 'Tom', 'Jack']
,'Age': [28, 25, 23]}
df = pd.DataFrame(data)
df
# Out:
#    Name  Age
# 0  John   28
# 1   Tom   25
# 2  Jack   23

# %%
a = pd.read_csv("https://raw.githubusercontent.com/dubey-dhananjay/Python/refs/heads/main/Codes/4%E1%B5%97%CA%B0_Data-Analysis_Python/3_Pandas/marksUT.csv" , header = 0)
a
# Out:
#         Name  UT  Maths  Science  S.St.  Hindi  Eng
# 0      Raman   1     22       21     18     20   21
# 1      Raman   2     21       20     17     22   24
# 2      Raman   3     14       19     15     24   23
# 3    Zuhaire   1     20       17     22     24   19
# 4    Zuhaire   2     23       15     21     25   15
# 5    Zuhaire   3     22       18     19     23   13
# 6   Aashravy   1     23       19     20     15   22
# 7   Aashravy   2     24       22     24     17   21
# 8   Aashravy   3     12       25     19     21   23
# 9     Mishti   1     15       22     25     22   22
# 10    Mishti   2     18       21     25     24   23
# 11    Mishti   3     17       18     20     25   20

# %%
ramanmarks = a.loc[a.Name == "Raman"]
ramanmarks
# Out:
#     Name  UT  Maths  Science  S.St.  Hindi  Eng
# 0  Raman   1     22       21     18     20   21
# 1  Raman   2     21       20     17     22   24
# 2  Raman   3     14       19     15     24   23

# %%
ramanmarks.sum(axis=1 , numeric_only=True)
# Out:
# 0    103
# 1    106
# 2     98
# dtype: int64

# %%
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [24, 27, 22]})

df.to_csv('output.csv' , index = False)

# %%
df = pd.read_excel("Book1.xlsx")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df = pd.read_excel("Book1.xlsx")
#       2 df
#
# File c:\Users\comp\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...
