# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
date = ["27/09" , "20,11" , "1/12"]

# %%
temp = [30 , 50 , 10]

# %%
a = plt.plot(date,temp)
a

# %%
plt.plot(date,temp)
plt.xlabel("Date")
plt.ylabel("Temperature")
plt.title("Date Wise Temperature")
plt.grid(True)

# %%
plt.plot(date, temp)
plt.xlabel("Date")                      # add the Label on x-axis
plt.ylabel("Temperature")               # add the Label on y-axis
plt.title("Date wise Temperature")      # add the Title to the chart
plt.grid(True)                          # add gridlines to the background
plt.yticks(temp)                        # add the exact numbers required on chart
# Out:
# ([<matplotlib.axis.YTick at 0x279b9e97610>,
#   <matplotlib.axis.YTick at 0x279b8ce0550>,
#   <matplotlib.axis.YTick at 0x279b8ce0cd0>],
#  [Text(0, 30, '30'), Text(0, 50, '50'), Text(0, 10, '10')])

# %%
plt.yticks(temp)
# Out:
# ([<matplotlib.axis.YTick at 0x279b8ce3b10>,
#   <matplotlib.axis.YTick at 0x279b8cfdd10>,
#   <matplotlib.axis.YTick at 0x279b8cfe490>],
#  [Text(0, 30, '30'), Text(0, 50, '50'), Text(0, 10, '10')])
