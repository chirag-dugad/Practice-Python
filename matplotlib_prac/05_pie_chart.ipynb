# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df = pd.DataFrame({
    "Mass": [0.330, 4.87, 5.97],
    "Radius": [2439.7, 6051.8, 6378.1]},
    index = ["Mercury", "Venus", "Earth"])

df.plot(kind="pie", y="Mass")
# Out:
# <Axes: ylabel='Mass'>

# %%
url = "https://raw.githubusercontent.com/dubey-dhananjay/Python/refs/heads/main/Codes/4%E1%B5%97%CA%B0_Data-Analysis_Python/4_Matplotlib/6-Pie_Chart/Forest_Cover.csv"

a = pd.read_csv(url , delimiter=",")
a
# Out:
#                State  GeoArea  ForestCover
# 0  Arunachal Pradesh    83743        67353
# 1              Assam    78438        27692
# 2            Manipur    22327        17280
# 3          Meghalaya    22429        17321
# 4            Mizoram    21081        19240
# 5           Nagaland    16579        13464
# 6            Tripura    10486         8073

# %%
a.plot(kind= "pie", y="ForestCover", title = "Forest Cover of Nort Eastern States", legend = False)
# Out:
# <Axes: title={'center': 'Forest Cover of Nort Eastern States'}, ylabel='ForestCover'>

# %%
df = pd.DataFrame({
    "Mass": [0.330, 4.87, 5.97],
    "Radius": [2439.7, 6051.8, 6378.1]},
    index = ["Mercury", "Venus", "Earth"])

df.plot(kind="pie", y="Radius")
# Out:
# <Axes: ylabel='Radius'>
