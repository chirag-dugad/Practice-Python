# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
discount = np.array([10, 20, 30, 40, 50])
SaleInRs = np.array([40000, 45000, 48000, 50000, 100000])

# %%
plt.scatter(x = discount, y = SaleInRs , marker="*" , color = "red" )
plt.title("Sales Vs Discount")
plt.xlabel("Discount Offered")
plt.ylabel("Sales in Rs")
# Out:
# Text(0, 0.5, 'Sales in Rs')

# %%
size = discount*10
plt.scatter(x = discount, y = SaleInRs, s = size, color="red", linewidth=3, marker="*", edgecolor = "blue")
plt.title("Sales Vs Discount")
plt.xlabel("Discount Offered")
plt.ylabel("Sales in Rs")
# Out:
# Text(0, 0.5, 'Sales in Rs')

# %%
size = discount*15
plt.scatter(x = discount , y = SaleInRs , marker = "*" , color = "red" , edgecolors = "blue" , s = size , linewidths=3)
plt.title("Sales Vs Discount")
plt.xlabel("Discount Offered")
plt.ylabel("Sales in Rs")
# Out:
# Text(0, 0.5, 'Sales in Rs')
